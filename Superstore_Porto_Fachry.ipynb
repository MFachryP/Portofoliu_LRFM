# %% [markdown]
# ## Datas
# ---
# | **Column Name**     | **Description**                                                                 |
# |---------------------|---------------------------------------------------------------------------------|
# | `Order ID`          | A unique ID for each order placed.                                             |
# | `Order Date`        | The date on which the order was placed.                                        |
# | `Customer Name`     | Name of the customer placing the order.                                        |
# | `Country`           | The country to which the customer belongs.                                     |
# | `State`             | The state to which the customer belongs from the country.                      |
# | `City`              | Detail about the city in which the customer resides.                           |
# | `Region`            | Contains the region details.                                                   |
# | `Segment`           | The ordered product belongs to what segment?                                   |
# | `Ship Mode`         | The mode of shipping of the order to the customer’s location.                  |
# | `Category`          | Contains the details about what category the product belongs to.              |
# | `Sub-category`      | Contains the details about what sub-category the product belongs to.           |
# | `Product Name`      | The name of the product ordered by the customer.                               |
# | `Discount`          | The discount applicable on a product.                                          |
# | `Sales`             | The actual sales happened for a particular order.                              |
# | `Profit`            | Profit earned on order.                                                        |
# | `Quantity`          | The total quantity of the product ordered in a single order.                   |
# | `Feedback`          | The feedback given by the customer on the complete shopping experience.        |
# |                     | If feedback is provided, then `TRUE`. If not, then `FALSE`.                    |

# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_excel(r"C:\Users\Axioo Pongo\Desktop\Purwadhika Exercise\Porto caps2\sales-superstore-activation.xlsx")

# %%
df.shape
# Out:
# (8047, 17)

# %%
df
# Out:
#              Order ID Order Date     Customer Name         Country  \
# 0     BN-2011-7407039 2011-01-01        Ruby Patel          Sweden
# 1     AZ-2011-9050313 2011-01-03    Summer Hayward  United Kingdom
# 2     AZ-2011-6674300 2011-01-04  Devin Huddleston          France
# 3     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# 4     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# ...               ...        ...               ...             ...
# 8042   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
# 8043  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8044  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8045  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8046   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
#
#                      State        City   Region      Segment     Ship Mode  \
# 0                Stockholm   Stockholm    North  Home Office  Economy Plus
# 1                  England   Southport    North     Consumer       Economy
# 2     Auvergne-Rhône-Alpes     Valence  Central     Consumer       Economy
# 3                  England  Birmingham    North    Corporate       Economy
# 4                  England  Birmingham    North    Corporate       Economy
# ...                    ...         ...      ...          ...           ...
# 8042               England  Maidenhead    North    Corporate       Economy
# 8043         North Brabant   Eindhoven  Central  Home Office  Economy Plus
# 8044         North Brabant   Eindhoven  Central  Home Office  Economy Plus
# 8045         North Brabant   Eindhoven  Central  Home Office  Economy Plus
# 8046               England  Maidenhead    North    Corporate       Economy
#
#              Category Sub-Category                           Product Name  \
# 0     Office Supplies        Paper            Enermax Note Cards, Premium
# 1           Furniture    Bookcases     Dania Corner Shelving, Traditional
# 2     Office Supplies          Art  Binney & Smith Sketch Pad, Easy-Erase
# 3     Office Supplies          Art             Boston Markers, Easy-Erase
# 4     Office Supplies      Storage            Eldon Folders, Single Width
# ...               ...          ...                                    ...
# 8042        Furniture    Bookcases   Ikea Stackable Bookrack, Traditional
# 8043  Office Supplies          Art      BIC Pencil Sharpener, Fluorescent
# 8044  Office Supplies      Binders          Avery Binder Covers, Recycled
# 8045       Technology     Machines                    StarTech Phone, Red
# 8046       Technology       Phones              Motorola Audio Dock, VoIP
#
#       Discount  Sales  Profit  Quantity  Feedback?
# 0          0.5     45     -26         3      False
# 1          0.0    854     290         7       True
# 2          0.0    140      21         3       True
# 3          0.5     27     -22         2       True
# 4          0.5     17      -1         2       True
# ...        ...    ...     ...       ...        ...
# 8042       0.0    245      91         2       True
# 8043       0.5     30     -10         2      False
# 8044       0.5     23      -6         4       True
# 8045       0.5    108     -19         3      False
# 8046       0.0    867     251         5      False
#
# [8047 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8047 entries, 0 to 8046
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       8047 non-null   object
#  1   Order Date     8047 non-null   datetime64[ns]
#  2   Customer Name  8047 non-null   object
#  3   Country        8047 non-null   object
#  4   State          8047 non-null   object
#  5   City           8047 non-null   object
#  6   Region         8047 non-null   object
#  7   Segment        8047 non-null   object
#  8   Ship Mode      8047 non-null   object
#  9   Category       8047 non-null   object
#  10  Sub-Category   8047 non-null   object
#  11  Product Name   8047 non-null   object
#  12  Discount       8047 non-null   float64
#  13  Sales          8047 non-null   int64
#  14  Profit         8047 non-null   int64
#  15  Quantity       8047 non-null   int64
#  16  Feedback?      8047 non-null   bool
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(3), object(11)
# memory usage: 1013.9+ KB

# %%
df.describe()
# Out:
#                           Order Date     Discount        Sales       Profit  \
# count                           8047  8047.000000  8047.000000  8047.000000
# mean   2013-04-19 12:25:40.748104704     0.110047   291.845657    35.198211
# min              2011-01-01 00:00:00     0.000000     3.000000 -3060.000000
# 25%              2012-06-08 00:00:00     0.000000    48.000000     1.000000
# 50%              2013-06-11 00:00:00     0.000000   117.000000    14.000000
# 75%              2014-04-30 00:00:00     0.100000   313.000000    47.000000
# max              2014-12-31 00:00:00     0.850000  6517.000000  2476.000000
# std                              NaN     0.181773   485.212156   178.125844
#
#           Quantity
# count  8047.000000
# mean      3.772089
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       5.000000
# max      14.000000
# std       2.203369

# %%
pd.DataFrame({
    'feature': df.columns.values,
    'data_type': df.dtypes.values,
    'missing_values': df.isnull().sum(),
    'missing_percentage': df.isnull().sum() / df.shape[0] * 100,
    'unique_values': df.nunique().values,
    'sample_unique': [df[col].unique() for col in df.columns]
    }).round(3)
# Out:
#                      feature       data_type  missing_values  \
# Order ID            Order ID          object               0
# Order Date        Order Date  datetime64[ns]               0
# Customer Name  Customer Name          object               0
# Country              Country          object               0
# State                  State          object               0
# City                    City          object               0
# Region                Region          object               0
# Segment              Segment          object               0
# Ship Mode          Ship Mode          object               0
# Category            Category          object               0
# Sub-Category    Sub-Category          object               0
# Product Name    Product Name          object               0
# Discount            Discount         float64               0
# Sales                  Sales           int64               0
# Profit                Profit           int64               0
# Quantity            Quantity           int64               0
# Feedback?          Feedback?            bool               0
#
#                missing_percentage  unique_values  \
# Order ID                      0.0           4117
# Order Date                    0.0           1214
# Customer Name                 0.0            792
# Country                       0.0             15
# State                         0.0            127
# City                          0.0            999
# Region                        0.0              3
# Segment                       0.0              3
# Ship Mode                     0.0              4
# Category                      0.0              3
# Sub-Category                  0.0             17
# Product Name                  0.0           1810
# Discount                      0.0             14
# Sales                         0.0           1248
# Profit                        0.0            845
# Quantity                      0.0             14
# Feedback?                     0.0              2
#
#                                                    sample_unique
# Order ID       [BN-2011-7407039, AZ-2011-9050313, AZ-2011-667...
# Order Date     [2011-01-01 00:00:00, 2011-01-03 00:00:00, 201...
# Customer Name  [Ruby Patel, Summer Hayward, Devin Huddleston,...
# Country        [Sweden, United Kingdom, France, Italy, Austri...
# State          [Stockholm, England, Auvergne-Rhône-Alpes, Pro...
# City           [Stockholm, Southport, Valence, Birmingham, Ec...
# Region                                   [North, Central, South]
# Segment                       [Home Office, Consumer, Corporate]
# Ship Mode           [Economy Plus, Economy, Priority, Immediate]
# Category                [Office Supplies, Furniture, Technology]
# Sub-Category   [Paper, Bookcases, Art, Storage, Fasteners, Bi...
# Product Name   [Enermax Note Cards, Premium, Dania Corner She...
# Discount       [0.5, 0.0, 0.1, 0.6, 0.4, 0.2, 0.65, 0.15, 0.7...
# Sales          [45, 854, 140, 27, 17, 90, 207, 155, 33, 716, ...
# Profit         [-26, 290, 21, -22, -1, 77, 36, 2, 143, -1012,...
# Quantity         [3, 7, 2, 4, 1, 6, 5, 11, 8, 10, 12, 9, 14, 13]
# Feedback?                                          [False, True]

# %%
df[df.duplicated()]
# Out:
#              Order ID Order Date      Customer Name  Country    State  \
# 2543  AZ-2012-5907386 2012-08-29       Louie Knight  Belgium  Antwerp
# 4066  AZ-2013-5637964 2013-06-14  Cynthia Zielinski    Spain   Madrid
#
#           City   Region      Segment Ship Mode         Category Sub-Category  \
# 2543  Mechelen  Central     Consumer   Economy  Office Supplies          Art
# 4066    Madrid    South  Home Office   Economy  Office Supplies      Binders
#
#                             Product Name  Discount  Sales  Profit  Quantity  \
# 2543           Sanford Pens, Fluorescent       0.0     37      10         3
# 4066  Wilson Jones 3-Hole Punch, Economy       0.0     84      28         3
#
#       Feedback?
# 2543      False
# 4066       True

# %%
df.drop_duplicates(inplace=True)

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
df
# Out:
#              Order ID Order Date     Customer Name         Country  \
# 0     BN-2011-7407039 2011-01-01        Ruby Patel          Sweden
# 1     AZ-2011-9050313 2011-01-03    Summer Hayward  United Kingdom
# 2     AZ-2011-6674300 2011-01-04  Devin Huddleston          France
# 3     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# 4     BN-2011-2819714 2011-01-04       Mary Parker  United Kingdom
# ...               ...        ...               ...             ...
# 8040   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
# 8041  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8042  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8043  BN-2014-4140795 2014-12-31   Daniel Hamilton     Netherlands
# 8044   AZ-2014-766953 2014-12-31      Jose Gambino  United Kingdom
#
#                      State        City   Region      Segment     Ship Mode  \
# 0                Stockholm   Stockholm    North  Home Office  Economy Plus
# 1                  England   Southport    North     Consumer       Economy
# 2     Auvergne-Rhône-Alpes     Valence  Central     Consumer       Economy
# 3                  England  Birmingham    North    Corporate       Economy
# 4                  England  Birmingham    North    Corporate       Economy
# ...                    ...         ...      ...          ...           ...
# 8040               England  Maidenhead    North    Corporate       Economy
# 8041         North Brabant   Eindhoven  Central  Home Office  Economy Plus
# 8042         North Brabant   Eindhoven  Central  Home Office  Economy Plus
# 8043         North Brabant   Eindhoven  Central  Home Office  Economy Plus
# 8044               England  Maidenhead    North    Corporate       Economy
#
#              Category Sub-Category                           Product Name  \
# 0     Office Supplies        Paper            Enermax Note Cards, Premium
# 1           Furniture    Bookcases     Dania Corner Shelving, Traditional
# 2     Office Supplies          Art  Binney & Smith Sketch Pad, Easy-Erase
# 3     Office Supplies          Art             Boston Markers, Easy-Erase
# 4     Office Supplies      Storage            Eldon Folders, Single Width
# ...               ...          ...                                    ...
# 8040        Furniture    Bookcases   Ikea Stackable Bookrack, Traditional
# 8041  Office Supplies          Art      BIC Pencil Sharpener, Fluorescent
# 8042  Office Supplies      Binders          Avery Binder Covers, Recycled
# 8043       Technology     Machines                    StarTech Phone, Red
# 8044       Technology       Phones              Motorola Audio Dock, VoIP
#
#       Discount  Sales  Profit  Quantity  Feedback?
# 0          0.5     45     -26         3      False
# 1          0.0    854     290         7       True
# 2          0.0    140      21         3       True
# 3          0.5     27     -22         2       True
# 4          0.5     17      -1         2       True
# ...        ...    ...     ...       ...        ...
# 8040       0.0    245      91         2       True
# 8041       0.5     30     -10         2      False
# 8042       0.5     23      -6         4       True
# 8043       0.5    108     -19         3      False
# 8044       0.0    867     251         5      False
#
# [8045 rows x 17 columns]

# %%
df.isna().sum()
# Out:
# Order ID         0
# Order Date       0
# Customer Name    0
# Country          0
# State            0
# City             0
# Region           0
# Segment          0
# Ship Mode        0
# Category         0
# Sub-Category     0
# Product Name     0
# Discount         0
# Sales            0
# Profit           0
# Quantity         0
# Feedback?        0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8040    False
# 8041    False
# 8042    False
# 8043    False
# 8044    False
# Length: 8045, dtype: bool

# %%
df.dtypes
# Out:
# Order ID                 object
# Order Date       datetime64[ns]
# Customer Name            object
# Country                  object
# State                    object
# City                     object
# Region                   object
# Segment                  object
# Ship Mode                object
# Category                 object
# Sub-Category             object
# Product Name             object
# Discount                float64
# Sales                     int64
# Profit                    int64
# Quantity                  int64
# Feedback?                  bool
# dtype: object

# %%
df.describe()
# Out:
#                           Order Date     Discount        Sales       Profit  \
# count                           8045  8045.000000  8045.000000  8045.000000
# mean   2013-04-19 12:57:32.778123008     0.110075   291.903170    35.202237
# min              2011-01-01 00:00:00     0.000000     3.000000 -3060.000000
# 25%              2012-06-08 00:00:00     0.000000    48.000000     1.000000
# 50%              2013-06-11 00:00:00     0.000000   117.000000    14.000000
# 75%              2014-04-30 00:00:00     0.100000   313.000000    47.000000
# max              2014-12-31 00:00:00     0.850000  6517.000000  2476.000000
# std                              NaN     0.181787   485.258616   178.147747
#
#           Quantity
# count  8045.000000
# mean      3.772281
# min       1.000000
# 25%       2.000000
# 50%       3.000000
# 75%       5.000000
# max      14.000000
# std       2.203610

# %% [markdown]
# ## LRFM Analysis Implementation

# %%
# Calculate the reference date (max order date + 1 day)
reference_date = df['Order Date'].max() + pd.Timedelta(days=1)

# Group by customer to calculate LRFM metrics
customer_data = df.groupby('Customer Name').agg({
    'Order Date': [
        ('recency', lambda x: (reference_date - x.max()).days),  # Recency: days since last purchase
        ('length', lambda x: (x.max() - x.min()).days)          # Length: days between first and last purchase
    ],
    'Order ID': [
        ('frequency', 'nunique')                                # Frequency: number of unique orders
    ],
    'Sales': [
        ('monetary', 'sum')                                     # Monetary: total sales amount
    ]
}).reset_index()

# Flatten the multi-index columns
customer_data.columns = ['Customer Name', 'recency', 'length', 'frequency', 'monetary']

# Calculate LRFM scores (quantile-based scoring)
def calculate_rfm_scores(df, column, ascending=True):
    # Higher score is better (1=lowest, 4=highest)
    return pd.qcut(df[column], q=4, labels=[1, 2, 3, 4], duplicates='drop')

customer_data['recency_score'] = calculate_rfm_scores(customer_data, 'recency', ascending=False)
customer_data['length_score'] = calculate_rfm_scores(customer_data, 'length')
customer_data['frequency_score'] = calculate_rfm_scores(customer_data, 'frequency')
customer_data['monetary_score'] = calculate_rfm_scores(customer_data, 'monetary')

# Calculate overall LRFM score (average of all dimensions)
customer_data['lrfm_score'] = (customer_data['recency_score'].astype(int) + 
                              customer_data['length_score'].astype(int) + 
                              customer_data['frequency_score'].astype(int) + 
                              customer_data['monetary_score'].astype(int)) / 4

# Create LRFM segments
def create_lrfm_segments(row):
    if row['lrfm_score'] >= 3.5:
        return 'Champions'
    elif row['lrfm_score'] >= 3.0:
        return 'Loyal Customers'
    elif row['lrfm_score'] >= 2.5:
        return 'Potential Loyalists'
    elif row['lrfm_score'] >= 2.0:
        return 'Recent Customers'
    elif row['lrfm_score'] >= 1.5:
        return 'Promising'
    elif row['lrfm_score'] >= 1.0:
        return 'Needs Attention'
    else:
        return 'At Risk'

customer_data['lrfm_segment'] = customer_data.apply(create_lrfm_segments, axis=1)

# Display the results
print("Customer LRFM Analysis Results:")
display(customer_data.head())

# Visualize the segments
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.countplot(data=customer_data, y='lrfm_segment', order=customer_data['lrfm_segment'].value_counts().index)
plt.title('Customer Segments Distribution')
plt.xlabel('Number of Customers')
plt.ylabel('LRFM Segment')
plt.show()

# Analyze segment characteristics
segment_analysis = customer_data.groupby('lrfm_segment').agg({
    'recency': 'mean',
    'length': 'mean',
    'frequency': 'mean',
    'monetary': 'mean',
    'Customer Name': 'count'
}).rename(columns={'Customer Name': 'count'}).sort_values('count', ascending=False)

print("\nSegment Characteristics:")
display(segment_analysis)
# Out:
# Customer LRFM Analysis Results:
#       Customer Name  recency  length  frequency  monetary recency_score  \
# 0     Aaron Bootman      253    1129         11      4281             3
# 1  Aaron Cunningham      212    1033          8      2463             3
# 2       Aaron Davey      637     560          4      2238             4
# 3   Aaron Macrossan     1200       0          1        81             4
# 4       Abbie Perry       98    1093          4      1313             2
#
#   length_score frequency_score monetary_score  lrfm_score      lrfm_segment
# 0            3               4              4        3.50         Champions
# 1            3               4              2        3.00   Loyal Customers
# 2            1               1              2        2.00  Recent Customers
# 3            1               1              1        1.75         Promising
# 4            3               1              2        2.00  Recent Customers
# Segment Characteristics:
#                         recency       length  frequency     monetary  count
# lrfm_segment
# Recent Customers     215.899123   867.052632   4.254386  2029.820175    228
# Potential Loyalists  153.000000  1033.031963   5.890411  3489.972603    219
# Loyal Customers      149.881579  1112.105263   7.019737  4785.118421    152
# Promising            328.280303   471.787879   2.871212   953.265152    132
# Champions            184.052632  1167.447368   9.131579  6499.526316     38
# Needs Attention       49.826087   470.304348   2.782609   917.695652     23
